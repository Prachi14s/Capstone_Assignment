# %% [markdown]
# **VISUALIZATIONS OF MALL CUSTOMER SEGMENTATION DATASET**

# %% [markdown]
# **Importing all necessary libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# **Read csv file into Python & first 5 columns of dataset**

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_4f40093b91404f7b9631704cfe14cee1 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='iUm5T-aUQbkJr38mZwbTdWR8CyZfu4ZKVT6iI0-1tdbA',
    ibm_auth_endpoint="https://iam.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_4f40093b91404f7b9631704cfe14cee1.get_object(Bucket='visualizationprojectmallsegmentat-donotdelete-pr-fk09wb2emij0st',Key='Mall_Customers.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#    CustomerID  Gender  Age  Annual Income  Spending Score
# 0           1    Male   19             15              39
# 1           2    Male   21             15              81
# 2           3  Female   20             16               6
# 3           4  Female   23             16              77
# 4           5  Female   31             17              40

# %% [markdown]
# **Let's see last 5 columns of dataset**

# %%
df_data_1.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income  Spending Score
# 195         196  Female   35            120              79
# 196         197  Female   45            126              28
# 197         198    Male   32            126              74
# 198         199    Male   32            137              18
# 199         200    Male   30            137              83

# %% [markdown]
# **Data information regarding its range, type, memory or null value count**

# %%
df_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
# CustomerID        200 non-null int64
# Gender            200 non-null object
# Age               200 non-null int64
# Annual Income     200 non-null int64
# Spending Score    200 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# **Data description in terms of statistical analysis**

# %%
df_data_1.describe()
# Out:
#        CustomerID         Age  Annual Income  Spending Score
# count  200.000000  200.000000     200.000000      200.000000
# mean   100.500000   38.850000      60.560000       50.200000
# std     57.879185   13.969007      26.264721       25.823522
# min      1.000000   18.000000      15.000000        1.000000
# 25%     50.750000   28.750000      41.500000       34.750000
# 50%    100.500000   36.000000      61.500000       50.000000
# 75%    150.250000   49.000000      78.000000       73.000000
# max    200.000000   70.000000     137.000000       99.000000

# %% [markdown]
# **Observing null values**

# %%
df_data_1.isnull().any()
# Out:
# CustomerID        False
# Gender            False
# Age               False
# Annual Income     False
# Spending Score    False
# dtype: bool

# %% [markdown]
# **All factors pair combination Visulaizations**

# %%
sns.pairplot(df_data_1)

# %% [markdown]
# **Scatter Plot of all factors in Dataset**

# %%
pd.scatter_matrix(df_data_1, alpha = 0.3, figsize = (10,6))
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   if __name__ == '__main__':
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8f9411a780>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8f86d15c50>]], dtype=object)

# %% [markdown]
# **Correlation MatPlot**

# %%
plt.matshow(df_data_1.corr())

# %% [markdown]
# **Range of Annual Income**

# %%
sns.set(style = 'whitegrid')
sns.distplot(df_data_1['Annual Income'])
plt.title('Distribution of Annual Income', fontsize = 20)
plt.xlabel('Range of Annual Income')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Range of Age**

# %%
sns.set(style = 'whitegrid')
sns.distplot(df_data_1['Age'])
plt.title('Distribution of Age', fontsize = 20)
plt.xlabel('Range of Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Percentage of Males & Females in Dataset**

# %%
df_data_1.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income', 'Spending Score'], dtype='object')

# %%
df_data_1['Gender'].value_counts()
# Out:
# Female    112
# Male       88
# Name: Gender, dtype: int64

# %%
labels = ['Female', 'Male']
size = [112, 88]
colors = ['violet', 'orange']
explode = [0, 0.1]

plt.rcParams['figure.figsize'] = (5,5)
plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, autopct = '%1.2f%%')
plt.title('A pie chart Representing the Gender')
plt.axis('off')
plt.legend()
plt.show()

# %% [markdown]
# **Age Count and it's visualization**

# %%
df_data_1['Age'].value_counts()
# Out:
# 32    11
# 35     9
# 19     8
# 31     8
# 30     7
# 49     7
# 27     6
# 47     6
# 40     6
# 23     6
# 36     6
# 38     6
# 50     5
# 48     5
# 29     5
# 21     5
# 20     5
# 34     5
# 18     4
# 28     4
# 59     4
# 24     4
# 67     4
# 54     4
# 39     3
# 25     3
# 33     3
# 22     3
# 37     3
# 43     3
# 68     3
# 45     3
# 46     3
# 60     3
# 41     2
# 57     2
# 66     2
# 65     2
# 63     2
# 58     2
# 26     2
# 70     2
# 42     2
# 53     2
# 52     2
# 51     2
# 44     2
# 55     1
# 64     1
# 69     1
# 56     1
# Name: Age, dtype: int64

# %%
df_data_1['Age'].value_counts().plot(kind='bar', figsize=(8,8))
plt.title("Representation of Age Distribution")
plt.xlabel("Age Distribution")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **Spending Score Count & it's visualization**

# %%
df_data_1['Spending Score'].value_counts()
# Out:
# 42    8
# 55    7
# 46    6
# 73    6
# 35    5
# 52    5
# 59    5
# 48    5
# 75    5
# 50    5
# 40    4
# 56    4
# 5     4
# 47    4
# 41    4
# 14    4
# 13    3
# 51    3
# 60    3
# 49    3
# 43    3
# 92    3
# 88    3
# 54    3
# 15    3
# 17    3
# 77    3
# 39    2
# 16    2
# 36    2
#      ..
# 61    2
# 58    2
# 18    1
# 9     1
# 8     1
# 11    1
# 12    1
# 7     1
# 94    1
# 3     1
# 89    1
# 53    1
# 27    1
# 85    1
# 68    1
# 98    1
# 63    1
# 65    1
# 66    1
# 45    1
# 44    1
# 71    1
# 22    1
# 78    1
# 34    1
# 31    1
# 82    1
# 24    1
# 23    1
# 99    1
# Name: Spending Score, Length: 84, dtype: int64

# %%
df_data_1['Spending Score'].value_counts().plot(kind='bar',figsize=(10,10))
plt.title("Representation of Spending Score Distribution")
plt.xlabel("Spending Score Distribution")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **Realtionship line between CustomerID & Annual Income**

# %%
x = df_data_1['CustomerID']
y = df_data_1['Annual Income']
plt.plot(x, y)
plt.title("Realtionship line between CustomerID & Annual Income")
plt.xlabel("CustomerID")
plt.ylabel("Annual Income")
plt.show()

# %% [markdown]
# **Realtionship line between Age & Spending Score**

# %%
x = df_data_1['Age']
y = df_data_1['Spending Score']
plt.plot(x,y)
plt.title("Realtionship line between Age & Spending Score")
plt.xlabel("Age")
plt.ylabel("Spending Score")
plt.show()

# %% [markdown]
# **Realtionship line between Annual Income & Spending Score**

# %%
x = df_data_1['Annual Income']
y = df_data_1['Spending Score']
plt.plot(x,y)
plt.title("Realtionship line between Annual Income & Spending Score")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.show()
